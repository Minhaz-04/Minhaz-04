# %% [markdown]
# <a href="https://colab.research.google.com/github/Minhaz-04/Minhaz-04/blob/main/Task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# **LOADING CSV FILE INTO A PANDAS DATAFRAME**

# %%
d = pd.read_csv(r"/content/01.Data Cleaning and Preprocessing.csv")
df=pd.DataFrame(d)

# %%
print(df)
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0      31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2      31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4      31-04:00    22.90    15.618      93.244  1334.168      243.131
# ..          ...      ...       ...         ...       ...          ...
# 319    10-16:00    23.75    12.667      93.450  1178.252      276.955
# 320     9-19:00    19.80    12.558      94.352  1184.119      297.071
# 321     9-20:00    23.01    12.550      90.842  1188.517      289.826
# 322     9-21:00    24.32    13.083      88.910  1192.879      318.006
# 323     9-22:00    25.75    13.417      85.451  1186.342      248.312
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %% [markdown]
# **FILTERING DATA BASED ON CONDITIONS**

# %%
df.loc[df['BlowFlow']<1000]
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 182     7-13:00    23.83    14.227         NaN     0.000      220.074
# 279    11-14:00    21.27    11.383      84.165   981.920      342.858
# 280    11-15:00    23.74    11.667      88.130   990.724      349.088
# 281    11-16:00    24.41    11.242      80.458   954.092      365.583
# 283    11-18:00    20.37    10.967      99.982   998.153      302.251
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# 182        352.981         323.718  1.416       594.970  ...        62.476
# 279        352.315         322.292  1.553       592.539  ...        73.134
# 280        349.697         311.997  1.555       579.875  ...        72.092
# 281        342.403         302.669  1.556       546.509  ...        68.806
# 283        344.295         305.080  1.604       471.537  ...        57.260
#
#      Lower-HeatT-3  Upper-HeatT-3   ChipMass-4   WeakLiquorF   BlackFlow-2   \
# ...

# %%
df.loc[df['UCZAA']<1.3]
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 37      1-12:00    14.53    10.833      93.121  1202.818      339.119
# 38      1-13:00    18.45    12.917      84.483  1175.728      391.599
# 78      3-05:00    20.60    13.420      80.236  1218.920      311.776
# 106     4-09:00    18.50    13.358      95.904  1281.919      225.252
# 107     4-10:00    19.95    13.367      98.838  1293.948      332.497
# 108     4-11:00    21.40    13.092      87.811  1296.683      324.450
# 109     4-12:00    22.80    14.767      77.912  1286.968      339.582
# 118     4-21:00    18.30    12.975      92.670  1276.523      325.519
# 119     4-22:00    20.55    13.775      88.829  1293.196      419.014
# 120     4-23:00    22.35    14.558      86.845  1293.985      402.245
# 121     5-00:00    25.56    14.900      84.953  1289.167      373.726
# 148     6-03:00    18.40    11.817      87.893  1268.595      384.941
# ...

# %%
df.loc[(df["BlowFlow"]<1100) & (df["UCZAA"]<1.4)]
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 286    11-21:00    19.53    11.245      92.564  1040.922      384.977
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# 286         342.79         284.633  1.368        444.58  ...        53.822
#
#      Lower-HeatT-3  Upper-HeatT-3   ChipMass-4   WeakLiquorF   BlackFlow-2   \
# 286        329.335         305.521      124.682       845.214       1301.95
#
#      WeakWashF   SteamHeatF-3   T-Top-Chips-4   SulphidityL-4
# 286     209.575         39.368         252.479             NaN
#
# [1 rows x 23 columns]

# %%
df.loc[(df["BlowFlow"]<1100) | (df["UCZAA"]<1.4)]
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 31      1-06:00    16.10    16.292      68.645  1094.883      245.962
# 36      1-11:00    12.81    10.942     114.567  1241.142      215.485
# 37      1-12:00    14.53    10.833      93.121  1202.818      339.119
# 38      1-13:00    18.45    12.917      84.483  1175.728      391.599
# 39      1-14:00    24.30    13.917      87.835  1190.889      390.140
# ..          ...      ...       ...         ...       ...          ...
# 287    11-22:00    21.20    11.292      92.194  1041.020      388.538
# 288    11-23:00    22.10    10.933      97.752  1038.618      333.743
# 289    12-00:00    22.50    10.625      89.193  1010.855      322.470
# 290    12-01:00    19.90    11.333      87.405  1033.565      369.383
# 291    12-02:00    21.00    11.825      90.949  1078.498      393.486
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
df.loc[(df["BlowFlow"]<1100)& (df["UCZAA"]<1.4)& (df["Y-Kappa"]<20)]
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 286    11-21:00    19.53    11.245      92.564  1040.922      384.977
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# 286         342.79         284.633  1.368        444.58  ...        53.822
#
#      Lower-HeatT-3  Upper-HeatT-3   ChipMass-4   WeakLiquorF   BlackFlow-2   \
# 286        329.335         305.521      124.682       845.214       1301.95
#
#      WeakWashF   SteamHeatF-3   T-Top-Chips-4   SulphidityL-4
# 286     209.575         39.368         252.479             NaN
#
# [1 rows x 23 columns]

# %% [markdown]
# **HANDLING MISSING VALUES**

# %%
df.dropna()
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 5       1-08:00    14.23    15.350      85.518  1171.604      198.538
# 7      31-06:00    22.65    14.100      91.887  1307.852      288.989
# 9      31-08:00    24.70    13.850      96.208  1334.892      362.511
# ..          ...      ...       ...         ...       ...          ...
# 312    31-10:00    24.40    14.117      85.998  1330.104      394.234
# 317     4-16:00    17.80    16.625      78.367  1276.082      202.744
# 319    10-16:00    23.75    12.667      93.450  1178.252      276.955
# 320     9-19:00    19.80    12.558      94.352  1184.119      297.071
# 322     9-21:00    24.32    13.083      88.910  1192.879      318.006
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 5       1-08:00    14.23    15.350      85.518  1171.604      198.538
# 7      31-06:00    22.65    14.100      91.887  1307.852      288.989
# 9      31-08:00    24.70    13.850      96.208  1334.892      362.511
# ..          ...      ...       ...         ...       ...          ...
# 312    31-10:00    24.40    14.117      85.998  1330.104      394.234
# 317     4-16:00    17.80    16.625      78.367  1276.082      202.744
# 319    10-16:00    23.75    12.667      93.450  1178.252      276.955
# 320     9-19:00    19.80    12.558      94.352  1184.119      297.071
# 322     9-21:00    24.32    13.083      88.910  1192.879      318.006
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
df['BlowFlow'].dropna()
# Out:
# 1      1328.360
# 3      1334.877
# 5      1171.604
# 7      1307.852
# 9      1334.892
#          ...
# 312    1330.104
# 317    1276.082
# 319    1178.252
# 320    1184.119
# 322    1192.879
# Name: BlowFlow, Length: 141, dtype: float64

# %%
df.loc[:,['BlowFlow','UCZAA']].dropna()
# Out:
#      BlowFlow  UCZAA
# 1    1328.360  1.549
# 3    1334.877  1.604
# 5    1171.604  1.436
# 7    1307.852  1.468
# 9    1334.892  1.515
# ..        ...    ...
# 312  1330.104  1.429
# 317  1276.082  1.488
# 319  1178.252  1.523
# 320  1184.119  1.451
# 322  1192.879  1.523
#
# [141 rows x 2 columns]

# %%
df.fillna("MISSING")
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 5       1-08:00    14.23    15.350      85.518  1171.604      198.538
# 7      31-06:00    22.65    14.100      91.887  1307.852      288.989
# 9      31-08:00    24.70    13.850      96.208  1334.892      362.511
# ..          ...      ...       ...         ...       ...          ...
# 312    31-10:00    24.40    14.117      85.998  1330.104      394.234
# 317     4-16:00    17.80    16.625      78.367  1276.082      202.744
# 319    10-16:00    23.75    12.667      93.450  1178.252      276.955
# 320     9-19:00    19.80    12.558      94.352  1184.119      297.071
# 322     9-21:00    24.32    13.083      88.910  1192.879      318.006
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
df.fillna("MISSING",inplace=True)
df
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 5       1-08:00    14.23    15.350      85.518  1171.604      198.538
# 7      31-06:00    22.65    14.100      91.887  1307.852      288.989
# 9      31-08:00    24.70    13.850      96.208  1334.892      362.511
# ..          ...      ...       ...         ...       ...          ...
# 312    31-10:00    24.40    14.117      85.998  1330.104      394.234
# 317     4-16:00    17.80    16.625      78.367  1276.082      202.744
# 319    10-16:00    23.75    12.667      93.450  1178.252      276.955
# 320     9-19:00    19.80    12.558      94.352  1184.119      297.071
# 322     9-21:00    24.32    13.083      88.910  1192.879      318.006
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
df['BlowFlow'].fillna(40)
# Out:
# 1      1328.360
# 3      1334.877
# 5      1171.604
# 7      1307.852
# 9      1334.892
#          ...
# 312    1330.104
# 317    1276.082
# 319    1178.252
# 320    1184.119
# 322    1192.879
# Name: BlowFlow, Length: 141, dtype: float64

# %%
import pandas as pd
d = pd.read_csv(r"/content/01.Data Cleaning and Preprocessing.csv")
df=pd.DataFrame(d)

# %%
df
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0      31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2      31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4      31-04:00    22.90    15.618      93.244  1334.168      243.131
# ..          ...      ...       ...         ...       ...          ...
# 319    10-16:00    23.75    12.667      93.450  1178.252      276.955
# 320     9-19:00    19.80    12.558      94.352  1184.119      297.071
# 321     9-20:00    23.01    12.550      90.842  1188.517      289.826
# 322     9-21:00    24.32    13.083      88.910  1192.879      318.006
# 323     9-22:00    25.75    13.417      85.451  1186.342      248.312
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
df['BlowFlow'].fillna(40)
# Out:
# 0      1177.607
# 1      1328.360
# 2      1329.407
# 3      1334.877
# 4      1334.168
#          ...
# 319    1178.252
# 320    1184.119
# 321    1188.517
# 322    1192.879
# 323    1186.342
# Name: BlowFlow, Length: 324, dtype: float64

# %%
df.loc[:,['BlowFlow','UCZAA']].fillna(45)
# Out:
#      BlowFlow   UCZAA
# 0    1177.607   1.443
# 1    1328.360   1.549
# 2    1329.407   1.600
# 3    1334.877   1.604
# 4    1334.168  45.000
# ..        ...     ...
# 319  1178.252   1.523
# 320  1184.119   1.451
# 321  1188.517   1.457
# 322  1192.879   1.523
# 323  1186.342   1.474
#
# [324 rows x 2 columns]

# %%
df['BlowFlow'].fillna(df['BlowFlow'].mean())
# Out:
# 0      1177.607
# 1      1328.360
# 2      1329.407
# 3      1334.877
# 4      1334.168
#          ...
# 319    1178.252
# 320    1184.119
# 321    1188.517
# 322    1192.879
# 323    1186.342
# Name: BlowFlow, Length: 324, dtype: float64

# %% [markdown]
# **CALCULATING SUMMARY STATISTICS**

# %%
df.count()
# Out:
# Observation        324
# Y-Kappa            324
# ChipRate           319
# BF-CMratio         307
# BlowFlow           308
# ChipLevel4         323
# T-upperExt-2       322
# T-lowerExt-2       322
# UCZAA              299
# WhiteFlow-4        323
# AAWhiteSt-4        173
# AA-Wood-4          323
# ChipMoisture-4     323
# SteamFlow-4        323
# Lower-HeatT-3      322
# Upper-HeatT-3      322
# ChipMass-4         323
# WeakLiquorF        323
# BlackFlow-2        322
# WeakWashF          323
# SteamHeatF-3       322
# T-Top-Chips-4      323
# SulphidityL-4      173
# dtype: int64

# %%
df["BF-CMratio"].head(20)
# Out:
# 0     121.717
# 1      79.022
# 2      79.562
# 3      81.011
# 4      93.244
# 5      85.518
# 6      98.186
# 7      91.887
# 8      97.249
# 9      96.208
# 10     95.720
# 11     85.998
# 12     84.447
# 13     82.839
# 14     77.025
# 15     72.924
# 16     79.387
# 17     87.057
# 18     92.772
# 19    100.073
# Name: BF-CMratio, dtype: float64

# %%
df['BlackFlow-2 '].value_counts()
# Out:
# BlackFlow-2
# 1319.664    3
# 1319.039    2
# 995.302     2
# 1297.317    2
# 1174.267    2
#            ..
# 934.048     1
# 899.259     1
# 959.878     1
# 1014.646    1
# 1323.082    1
# Name: count, Length: 296, dtype: int64

# %%
df['SulphidityL-4 '].min()
# Out:
# 29.01

# %%
df['SulphidityL-4 '].nsmallest(4)
# Out:
# 4      29.01
# 306    29.01
# 3      29.02
# 305    29.02
# Name: SulphidityL-4 , dtype: float64

# %%
df['SulphidityL-4 '].max()
# Out:
# 32.84

# %%
df['SulphidityL-4 '].nlargest(4)
# Out:
# 154    32.840
# 82     32.020
# 80     31.910
# 121    31.796
# Name: SulphidityL-4 , dtype: float64

# %%
df[["Lower-HeatT-3", "BlowFlow", "UCZAA"]].mean(axis=1)
# Out:
# 0      502.827333
# 1      553.577333
# 2      553.382333
# 3      555.118667
# 4      831.260000
#           ...
# 319    503.297333
# 320    505.472667
# 321    506.733333
# 322    507.249333
# 323    505.302667
# Length: 324, dtype: float64

# %%
df[["Lower-HeatT-3", "BlowFlow", "UCZAA"]].median(axis=1)
# Out:
# 0      329.432
# 1      330.823
# 2      329.140
# 3      328.875
# 4      831.260
#         ...
# 319    330.117
# 320    330.848
# 321    330.226
# 322    327.346
# 323    328.092
# Length: 324, dtype: float64

# %%
df['ChipRate'].mode()
# Out:
# 0    15.8
# Name: ChipRate, dtype: float64

# %%
df[["Lower-HeatT-3", "BlowFlow", "UCZAA"]].std()
# Out:
# Lower-HeatT-3      4.609862
# BlowFlow         100.593735
# UCZAA              0.105923
# dtype: float64

# %%
df["Lower-HeatT-3"].agg(["mean", "median", "std"])
# Out:
# mean      325.567820
# median    324.741000
# std         4.609862
# Name: Lower-HeatT-3, dtype: float64

# %%
df.describe()
# Out:
#           Y-Kappa    ChipRate  BF-CMratio     BlowFlow  ChipLevel4   \
# count  324.000000  319.000000  307.000000   308.000000   323.000000
# mean    20.635370   14.347937   87.464456  1237.837614   258.164483
# std      3.070036    1.499095    7.995012   100.593735    87.987452
# min     12.170000    9.983000   68.645000     0.000000     0.000000
# 25%     18.382500   13.358000   81.823000  1193.215250   213.527000
# 50%     20.845000   14.308000   86.739000  1273.138500   271.792000
# 75%     23.032500   15.517000   92.372000  1289.196000   321.680000
# max     27.600000   16.958000  121.717000  1351.240000   419.014000
#
#        T-upperExt-2   T-lowerExt-2         UCZAA  WhiteFlow-4   AAWhiteSt-4   \
# count     322.000000      322.000000  299.000000    323.000000    173.000000
# mean      356.904295      324.020180    1.492010    591.732260      6.140410
# std         9.209290        7.621402    0.105923     67.016351      0.081609
# ...
